# %%
import preprocessingFuncts as pp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Best and Worst User Data

# %% [markdown]
# Unweighted User Data

# %%
b= pp.Unweighteduserdata("gender")
for n in b:
    display(n)
# Out:
#        user_id  item_id  rating  average_rating
# 99960       60     1122       5             5.0
# 99791      437     1599       5             5.0
# 99961       90     1201       5             5.0
# 96399       13      814       5             5.0
# 99243      146     1293       5             5.0
# ...        ...      ...     ...             ...
# 98403      405     1582       1             1.0
# 99506      405     1579       1             1.0
# 87872      181     1320       1             1.0
# 99928      279     1494       1             1.0
# 99426      405     1587       1             1.0
#
# [100000 rows x 4 columns]
# <style type="text/css">
# </style>
# <table id="T_d827b">
#   <caption>Gender 0 Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d827b_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_d827b_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
# ...

# %%
b= pp.Unweighteduserdata("occupation")
for n in b:
    display(n)
# Out:
#        user_id  item_id  rating  average_rating
# 99960       60     1122       5             5.0
# 99791      437     1599       5             5.0
# 99961       90     1201       5             5.0
# 96399       13      814       5             5.0
# 99243      146     1293       5             5.0
# ...        ...      ...     ...             ...
# 98403      405     1582       1             1.0
# 99506      405     1579       1             1.0
# 87872      181     1320       1             1.0
# 99928      279     1494       1             1.0
# 99426      405     1587       1             1.0
#
# [100000 rows x 4 columns]
# <style type="text/css">
# </style>
# <table id="T_39b23">
#   <caption>Occupation 0 Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39b23_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_39b23_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
# ...

# %%
b= pp.Unweighteduserdata("age_group")
for n in b:
    display(n)
# Out:
#        user_id  item_id  rating  average_rating
# 99960       60     1122       5             5.0
# 99791      437     1599       5             5.0
# 99961       90     1201       5             5.0
# 96399       13      814       5             5.0
# 99243      146     1293       5             5.0
# ...        ...      ...     ...             ...
# 98403      405     1582       1             1.0
# 99506      405     1579       1             1.0
# 87872      181     1320       1             1.0
# 99928      279     1494       1             1.0
# 99426      405     1587       1             1.0
#
# [100000 rows x 4 columns]
# <style type="text/css">
# </style>
# <table id="T_04ae7">
#   <caption>Age Group 0 Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04ae7_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_04ae7_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Weighted User Data

# %%
a = pp.Weighteduserdata(30,"gender")
for i in a:
    display(i)
# Out:
#        user_id  item_id  rating  average_rating  count
# 28164       14      408       5        4.491071    112
# 28217      864      408       5        4.491071    112
# 28204       70      408       4        4.491071    112
# 28203      637      408       5        4.491071    112
# 28202      363      408       5        4.491071    112
# ...        ...      ...     ...             ...    ...
# 29141      181      688       1        1.840909     44
# 29142       30      688       3        1.840909     44
# 29154      587      688       3        1.840909     44
# 29155      296      688       1        1.840909     44
# 29153       13      688       1        1.840909     44
#
# [91726 rows x 5 columns]
# <style type="text/css">
# </style>
# <table id="T_2757e">
#   <caption>Gender 0 Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2757e_level0_col0" class="col_heading level0 col0" >item_id</th>
# ...

# %%
a = pp.Weighteduserdata(30,"occupation")
for i in a:
    display(i)
# Out:
#        user_id  item_id  rating  average_rating  count
# 28164       14      408       5        4.491071    112
# 28217      864      408       5        4.491071    112
# 28204       70      408       4        4.491071    112
# 28203      637      408       5        4.491071    112
# 28202      363      408       5        4.491071    112
# ...        ...      ...     ...             ...    ...
# 29141      181      688       1        1.840909     44
# 29142       30      688       3        1.840909     44
# 29154      587      688       3        1.840909     44
# 29155      296      688       1        1.840909     44
# 29153       13      688       1        1.840909     44
#
# [91726 rows x 5 columns]
# <style type="text/css">
# </style>
# <table id="T_f66b2">
#   <caption>Occupation 0 Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f66b2_level0_col0" class="col_heading level0 col0" >item_id</th>
# ...

# %%
a = pp.Weighteduserdata(30,"age_group")
for i in a:
    display(i)
# Out:
#        user_id  item_id  rating  average_rating  count
# 28164       14      408       5        4.491071    112
# 28217      864      408       5        4.491071    112
# 28204       70      408       4        4.491071    112
# 28203      637      408       5        4.491071    112
# 28202      363      408       5        4.491071    112
# ...        ...      ...     ...             ...    ...
# 29141      181      688       1        1.840909     44
# 29142       30      688       3        1.840909     44
# 29154      587      688       3        1.840909     44
# 29155      296      688       1        1.840909     44
# 29153       13      688       1        1.840909     44
#
# [91726 rows x 5 columns]
# <style type="text/css">
# </style>
# <table id="T_264cc">
#   <caption>Age group 0 Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_264cc_level0_col0" class="col_heading level0 col0" >item_id</th>
# ...

# %% [markdown]
# Weighted Item Data

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"unknown")
if c==None:
    print (c)
else:
    display(c)
# Out:
# Weighted data for Unknown genre does not exist
# None

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Action")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_46836">
#   <caption>Action Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46836_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_46836_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46836_level0_row0" class="row_heading level0 row0" >4.358491</th>
#       <td id="T_46836_row0_col0" class="data row0 col0" >50</td>
#       <td id="T_46836_row0_col1" class="data row0 col1" >Star Wars (1977)</td>
#     </tr>
#     <tr>
#       <th id="T_46836_level0_row1" class="row_heading level0 row1" >4.283293</th>
#       <td id="T_46836_row1_col0" class="data row1 col0" >127</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Adventure")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3439f">
#   <caption>Adventure Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3439f_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_3439f_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3439f_level0_row0" class="row_heading level0 row0" >4.358491</th>
#       <td id="T_3439f_row0_col0" class="data row0 col0" >50</td>
#       <td id="T_3439f_row0_col1" class="data row0 col1" >Star Wars (1977)</td>
#     </tr>
#     <tr>
#       <th id="T_3439f_level0_row1" class="row_heading level0 row1" >4.252381</th>
#       <td id="T_3439f_row1_col0" class="data row1 col0" >174</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Animation")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_99a12">
#   <caption>Animation Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99a12_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_99a12_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99a12_level0_row0" class="row_heading level0 row0" >4.491071</th>
#       <td id="T_99a12_row0_col0" class="data row0 col0" >408</td>
#       <td id="T_99a12_row0_col1" class="data row0 col1" >Close Shave, A (1995)</td>
#     </tr>
#     <tr>
#       <th id="T_99a12_level0_row1" class="row_heading level0 row1" >4.466102</th>
#       <td id="T_99a12_row1_col0" class="data row1 col0" >169</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Children's")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0beaf">
#   <caption>Children's Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0beaf_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_0beaf_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0beaf_level0_row0" class="row_heading level0 row0" >4.077236</th>
#       <td id="T_0beaf_row0_col0" class="data row0 col0" >132</td>
#       <td id="T_0beaf_row0_col1" class="data row0 col1" >Wizard of Oz, The (1939)</td>
#     </tr>
#     <tr>
#       <th id="T_0beaf_level0_row1" class="row_heading level0 row1" >3.995434</th>
#       <td id="T_0beaf_row1_col0" class="data row1 col0" >8</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Comedy")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d1fac">
#   <caption>Comedy Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1fac_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_d1fac_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1fac_level0_row0" class="row_heading level0 row0" >4.491071</th>
#       <td id="T_d1fac_row0_col0" class="data row0 col0" >408</td>
#       <td id="T_d1fac_row0_col1" class="data row0 col1" >Close Shave, A (1995)</td>
#     </tr>
#     <tr>
#       <th id="T_d1fac_level0_row1" class="row_heading level0 row1" >4.466102</th>
#       <td id="T_d1fac_row1_col0" class="data row1 col0" >169</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Crime")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b494">
#   <caption>Crime Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b494_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_6b494_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b494_level0_row0" class="row_heading level0 row0" >4.385768</th>
#       <td id="T_6b494_row0_col0" class="data row0 col0" >12</td>
#       <td id="T_6b494_row0_col1" class="data row0 col1" >Usual Suspects, The (1995)</td>
#     </tr>
#     <tr>
#       <th id="T_6b494_level0_row1" class="row_heading level0 row1" >4.283293</th>
#       <td id="T_6b494_row1_col0" class="data row1 col0" >127</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Documentary")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3dfc7">
#   <caption>Documentary Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dfc7_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_3dfc7_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dfc7_level0_row0" class="row_heading level0 row0" >4.094017</th>
#       <td id="T_3dfc7_row0_col0" class="data row0 col0" >48</td>
#       <td id="T_3dfc7_row0_col1" class="data row0 col1" >Hoop Dreams (1994)</td>
#     </tr>
#     <tr>
#       <th id="T_3dfc7_level0_row1" class="row_heading level0 row1" >4.045455</th>
#       <td id="T_3dfc7_row1_col0" class="data row1 col0" >1142</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Drama")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e854">
#   <caption>Drama Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e854_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_5e854_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e854_level0_row0" class="row_heading level0 row0" >4.466443</th>
#       <td id="T_5e854_row0_col0" class="data row0 col0" >318</td>
#       <td id="T_5e854_row0_col1" class="data row0 col1" >Schindler's List (1993)</td>
#     </tr>
#     <tr>
#       <th id="T_5e854_level0_row1" class="row_heading level0 row1" >4.456790</th>
#       <td id="T_5e854_row1_col0" class="data row1 col0" >483</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Fantasy")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a8572">
#   <caption>Fantasy Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8572_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_a8572_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8572_level0_row0" class="row_heading level0 row0" >3.833333</th>
#       <td id="T_a8572_row0_col0" class="data row0 col0" >423</td>
#       <td id="T_a8572_row0_col1" class="data row0 col1" >E.T. the Extra-Terrestrial (1982)</td>
#     </tr>
#     <tr>
#       <th id="T_a8572_level0_row1" class="row_heading level0 row1" >3.671429</th>
#       <td id="T_a8572_row1_col0" class="data row1 col0" >558</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Film-Noir")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fcb65">
#   <caption>Film-Noir Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcb65_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_fcb65_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcb65_level0_row0" class="row_heading level0 row0" >4.259542</th>
#       <td id="T_fcb65_row0_col0" class="data row0 col0" >657</td>
#       <td id="T_fcb65_row0_col1" class="data row0 col1" >Manchurian Candidate, The (1962)</td>
#     </tr>
#     <tr>
#       <th id="T_fcb65_level0_row1" class="row_heading level0 row1" >4.210145</th>
#       <td id="T_fcb65_row1_col0" class="data row1 col0" >484</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Horror")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0b5d0">
#   <caption>Horror Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b5d0_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_0b5d0_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b5d0_level0_row0" class="row_heading level0 row0" >4.100418</th>
#       <td id="T_0b5d0_row0_col0" class="data row0 col0" >185</td>
#       <td id="T_0b5d0_row0_col1" class="data row0 col1" >Psycho (1960)</td>
#     </tr>
#     <tr>
#       <th id="T_0b5d0_level0_row1" class="row_heading level0 row1" >4.034364</th>
#       <td id="T_0b5d0_row1_col0" class="data row1 col0" >183</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Musical")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6be9f">
#   <caption>Musical Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6be9f_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_6be9f_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6be9f_level0_row0" class="row_heading level0 row0" >4.077236</th>
#       <td id="T_6be9f_row0_col0" class="data row0 col0" >132</td>
#       <td id="T_6be9f_row0_col1" class="data row0 col1" >Wizard of Oz, The (1939)</td>
#     </tr>
#     <tr>
#       <th id="T_6be9f_level0_row1" class="row_heading level0 row1" >3.992701</th>
#       <td id="T_6be9f_row1_col0" class="data row1 col0" >705</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Mystery")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_375fa">
#   <caption>Mystery Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_375fa_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_375fa_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_375fa_level0_row0" class="row_heading level0 row0" >4.387560</th>
#       <td id="T_375fa_row0_col0" class="data row0 col0" >603</td>
#       <td id="T_375fa_row0_col1" class="data row0 col1" >Rear Window (1954)</td>
#     </tr>
#     <tr>
#       <th id="T_375fa_level0_row1" class="row_heading level0 row1" >4.333333</th>
#       <td id="T_375fa_row1_col0" class="data row1 col0" >513</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Romance")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_857e0">
#   <caption>Romance Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_857e0_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_857e0_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_857e0_level0_row0" class="row_heading level0 row0" >4.456790</th>
#       <td id="T_857e0_row0_col0" class="data row0 col0" >483</td>
#       <td id="T_857e0_row0_col1" class="data row0 col1" >Casablanca (1942)</td>
#     </tr>
#     <tr>
#       <th id="T_857e0_level0_row1" class="row_heading level0 row1" >4.358491</th>
#       <td id="T_857e0_row1_col0" class="data row1 col0" >50</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Sci-Fi")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4debc">
#   <caption>Sci-Fi Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4debc_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_4debc_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4debc_level0_row0" class="row_heading level0 row0" >4.358491</th>
#       <td id="T_4debc_row0_col0" class="data row0 col0" >50</td>
#       <td id="T_4debc_row0_col1" class="data row0 col1" >Star Wars (1977)</td>
#     </tr>
#     <tr>
#       <th id="T_4debc_level0_row1" class="row_heading level0 row1" >4.252577</th>
#       <td id="T_4debc_row1_col0" class="data row1 col0" >474</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Thriller")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_805a3">
#   <caption>Thriller Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_805a3_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_805a3_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_805a3_level0_row0" class="row_heading level0 row0" >4.491071</th>
#       <td id="T_805a3_row0_col0" class="data row0 col0" >408</td>
#       <td id="T_805a3_row0_col1" class="data row0 col1" >Close Shave, A (1995)</td>
#     </tr>
#     <tr>
#       <th id="T_805a3_level0_row1" class="row_heading level0 row1" >4.387560</th>
#       <td id="T_805a3_row1_col0" class="data row1 col0" >603</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"War")
for x in c:
    display(x)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6bc10">
#   <caption>War Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bc10_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_6bc10_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bc10_level0_row0" class="row_heading level0 row0" >4.466443</th>
#       <td id="T_6bc10_row0_col0" class="data row0 col0" >318</td>
#       <td id="T_6bc10_row0_col1" class="data row0 col1" >Schindler's List (1993)</td>
#     </tr>
#     <tr>
#       <th id="T_6bc10_level0_row1" class="row_heading level0 row1" >4.456790</th>
#       <td id="T_6bc10_row1_col0" class="data row1 col0" >483</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
c= pp.Weighteditemdata(30,"Western")
for x in c:
    display(x)
# d= pp.Unweighteditemdata("Action")
# for y in d:
#     display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_33ddf">
#   <caption>Western Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33ddf_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_33ddf_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33ddf_level0_row0" class="row_heading level0 row0" >4.102273</th>
#       <td id="T_33ddf_row0_col0" class="data row0 col0" >661</td>
#       <td id="T_33ddf_row0_col1" class="data row0 col1" >High Noon (1952)</td>
#     </tr>
#     <tr>
#       <th id="T_33ddf_level0_row1" class="row_heading level0 row1" >4.023256</th>
#       <td id="T_33ddf_row1_col0" class="data row1 col0" >589</td>
# ...

# %% [markdown]
# Unweighted Item Data

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("unknown")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_91a21">
#   <caption>unknown Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91a21_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_91a21_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91a21_level0_row0" class="row_heading level0 row0" >3.444444</th>
#       <td id="T_91a21_row0_col0" class="data row0 col0" >267</td>
#       <td id="T_91a21_row0_col1" class="data row0 col1" >unknown</td>
#     </tr>
#     <tr>
#       <th id="T_91a21_level0_row1" class="row_heading level0 row1" >1.000000</th>
#       <td id="T_91a21_row1_col0" class="data row1 col0" >1373</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Action")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f6b01">
#   <caption>Action Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6b01_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_f6b01_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6b01_level0_row0" class="row_heading level0 row0" >4.358491</th>
#       <td id="T_f6b01_row0_col0" class="data row0 col0" >50</td>
#       <td id="T_f6b01_row0_col1" class="data row0 col1" >Star Wars (1977)</td>
#     </tr>
#     <tr>
#       <th id="T_f6b01_level0_row1" class="row_heading level0 row1" >4.283293</th>
#       <td id="T_f6b01_row1_col0" class="data row1 col0" >127</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Adventure")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_cd4b8">
#   <caption>Adventure Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd4b8_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_cd4b8_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd4b8_level0_row0" class="row_heading level0 row0" >5.000000</th>
#       <td id="T_cd4b8_row0_col0" class="data row0 col0" >1293</td>
#       <td id="T_cd4b8_row0_col1" class="data row0 col1" >Star Kid (1997)</td>
#     </tr>
#     <tr>
#       <th id="T_cd4b8_level0_row1" class="row_heading level0 row1" >4.358491</th>
#       <td id="T_cd4b8_row1_col0" class="data row1 col0" >50</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Animation")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4918c">
#   <caption>Animation Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4918c_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_4918c_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4918c_level0_row0" class="row_heading level0 row0" >4.491071</th>
#       <td id="T_4918c_row0_col0" class="data row0 col0" >408</td>
#       <td id="T_4918c_row0_col1" class="data row0 col1" >Close Shave, A (1995)</td>
#     </tr>
#     <tr>
#       <th id="T_4918c_level0_row1" class="row_heading level0 row1" >4.466102</th>
#       <td id="T_4918c_row1_col0" class="data row1 col0" >169</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Children's")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3ba74">
#   <caption>Children's Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ba74_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_3ba74_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ba74_level0_row0" class="row_heading level0 row0" >5.000000</th>
#       <td id="T_3ba74_row0_col0" class="data row0 col0" >1293</td>
#       <td id="T_3ba74_row0_col1" class="data row0 col1" >Star Kid (1997)</td>
#     </tr>
#     <tr>
#       <th id="T_3ba74_level0_row1" class="row_heading level0 row1" >4.077236</th>
#       <td id="T_3ba74_row1_col0" class="data row1 col0" >132</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Comedy")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_86e7d">
#   <caption>Comedy Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86e7d_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_86e7d_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86e7d_level0_row0" class="row_heading level0 row0" >5.000000</th>
#       <td id="T_86e7d_row0_col0" class="data row0 col0" >1500</td>
#       <td id="T_86e7d_row0_col1" class="data row0 col1" >Santa with Muscles (1996)</td>
#     </tr>
#     <tr>
#       <th id="T_86e7d_level0_row1" class="row_heading level0 row1" >4.491071</th>
#       <td id="T_86e7d_row1_col0" class="data row1 col0" >408</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Crime")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dda33">
#   <caption>Crime Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dda33_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_dda33_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dda33_level0_row0" class="row_heading level0 row0" >5.000000</th>
#       <td id="T_dda33_row0_col0" class="data row0 col0" >1122</td>
#       <td id="T_dda33_row0_col1" class="data row0 col1" >They Made Me a Criminal (1939)</td>
#     </tr>
#     <tr>
#       <th id="T_dda33_level0_row1" class="row_heading level0 row1" >4.385768</th>
#       <td id="T_dda33_row1_col0" class="data row1 col0" >12</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Documentary")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5a8d">
#   <caption>Documentary Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5a8d_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_c5a8d_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5a8d_level0_row0" class="row_heading level0 row0" >5.000000</th>
#       <td id="T_c5a8d_row0_col0" class="data row0 col0" >1201</td>
#       <td id="T_c5a8d_row0_col1" class="data row0 col1" >Marlene Dietrich: Shadow and Light (1996) </td>
#     </tr>
#     <tr>
#       <th id="T_c5a8d_level0_row1" class="row_heading level0 row1" >4.500000</th>
#       <td id="T_c5a8d_row1_col0" class="data row1 col0" >1594</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Drama")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a856b">
#   <caption>Drama Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a856b_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_a856b_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a856b_level0_row0" class="row_heading level0 row0" >5.000000</th>
#       <td id="T_a856b_row0_col0" class="data row0 col0" >1653</td>
#       <td id="T_a856b_row0_col1" class="data row0 col1" >They Made Me a Criminal (1939)</td>
#     </tr>
#     <tr>
#       <th id="T_a856b_level0_row1" class="row_heading level0 row1" >4.625000</th>
#       <td id="T_a856b_row1_col0" class="data row1 col0" >1449</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Fantasy")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a6238">
#   <caption>Fantasy Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6238_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_a6238_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6238_level0_row0" class="row_heading level0 row0" >5.000000</th>
#       <td id="T_a6238_row0_col0" class="data row0 col0" >1293</td>
#       <td id="T_a6238_row0_col1" class="data row0 col1" >Star Kid (1997)</td>
#     </tr>
#     <tr>
#       <th id="T_a6238_level0_row1" class="row_heading level0 row1" >3.833333</th>
#       <td id="T_a6238_row1_col0" class="data row1 col0" >423</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Film-Noir")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_83456">
#   <caption>Film-Noir Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83456_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_83456_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83456_level0_row0" class="row_heading level0 row0" >4.259542</th>
#       <td id="T_83456_row0_col0" class="data row0 col0" >657</td>
#       <td id="T_83456_row0_col1" class="data row0 col1" >Manchurian Candidate, The (1962)</td>
#     </tr>
#     <tr>
#       <th id="T_83456_level0_row1" class="row_heading level0 row1" >4.250000</th>
#       <td id="T_83456_row1_col0" class="data row1 col0" >1064</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Horror")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a7909">
#   <caption>Horror Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7909_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_a7909_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7909_level0_row0" class="row_heading level0 row0" >4.100418</th>
#       <td id="T_a7909_row0_col0" class="data row0 col0" >185</td>
#       <td id="T_a7909_row0_col1" class="data row0 col1" >Psycho (1960)</td>
#     </tr>
#     <tr>
#       <th id="T_a7909_level0_row1" class="row_heading level0 row1" >4.034364</th>
#       <td id="T_a7909_row1_col0" class="data row1 col0" >183</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Musical")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ee88e">
#   <caption>Musical Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee88e_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_ee88e_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee88e_level0_row0" class="row_heading level0 row0" >4.077236</th>
#       <td id="T_ee88e_row0_col0" class="data row0 col0" >132</td>
#       <td id="T_ee88e_row0_col1" class="data row0 col1" >Wizard of Oz, The (1939)</td>
#     </tr>
#     <tr>
#       <th id="T_ee88e_level0_row1" class="row_heading level0 row1" >4.047619</th>
#       <td id="T_ee88e_row1_col0" class="data row1 col0" >1203</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Mystery")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8342">
#   <caption>Mystery Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8342_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_b8342_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8342_level0_row0" class="row_heading level0 row0" >4.387560</th>
#       <td id="T_b8342_row0_col0" class="data row0 col0" >603</td>
#       <td id="T_b8342_row0_col1" class="data row0 col1" >Rear Window (1954)</td>
#     </tr>
#     <tr>
#       <th id="T_b8342_level0_row1" class="row_heading level0 row1" >4.333333</th>
#       <td id="T_b8342_row1_col0" class="data row1 col0" >513</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Romance")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c8b29">
#   <caption>Romance Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8b29_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_c8b29_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8b29_level0_row0" class="row_heading level0 row0" >4.456790</th>
#       <td id="T_c8b29_row0_col0" class="data row0 col0" >483</td>
#       <td id="T_c8b29_row0_col1" class="data row0 col1" >Casablanca (1942)</td>
#     </tr>
#     <tr>
#       <th id="T_c8b29_level0_row1" class="row_heading level0 row1" >4.358491</th>
#       <td id="T_c8b29_row1_col0" class="data row1 col0" >50</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Sci-Fi")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_05d9d">
#   <caption>Sci-Fi Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05d9d_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_05d9d_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05d9d_level0_row0" class="row_heading level0 row0" >5.000000</th>
#       <td id="T_05d9d_row0_col0" class="data row0 col0" >1293</td>
#       <td id="T_05d9d_row0_col1" class="data row0 col1" >Star Kid (1997)</td>
#     </tr>
#     <tr>
#       <th id="T_05d9d_level0_row1" class="row_heading level0 row1" >4.358491</th>
#       <td id="T_05d9d_row1_col0" class="data row1 col0" >50</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Thriller")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e6997">
#   <caption>Thriller Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6997_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_e6997_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6997_level0_row0" class="row_heading level0 row0" >4.491071</th>
#       <td id="T_e6997_row0_col0" class="data row0 col0" >408</td>
#       <td id="T_e6997_row0_col1" class="data row0 col1" >Close Shave, A (1995)</td>
#     </tr>
#     <tr>
#       <th id="T_e6997_level0_row1" class="row_heading level0 row1" >4.387560</th>
#       <td id="T_e6997_row1_col0" class="data row1 col0" >603</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("War")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_28b75">
#   <caption>War Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28b75_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_28b75_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28b75_level0_row0" class="row_heading level0 row0" >4.466443</th>
#       <td id="T_28b75_row0_col0" class="data row0 col0" >318</td>
#       <td id="T_28b75_row0_col1" class="data row0 col1" >Schindler's List (1993)</td>
#     </tr>
#     <tr>
#       <th id="T_28b75_level0_row1" class="row_heading level0 row1" >4.456790</th>
#       <td id="T_28b75_row1_col0" class="data row1 col0" >483</td>
# ...

# %%
#["unknown", "Action", "Adventure", "Animation", "Children's","Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
d= pp.Unweighteditemdata("Western")
for y in d:
    display(y)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bc3ed">
#   <caption>Western Max:</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc3ed_level0_col0" class="col_heading level0 col0" >item_id</th>
#       <th id="T_bc3ed_level0_col1" class="col_heading level0 col1" >title</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >average_rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc3ed_level0_row0" class="row_heading level0 row0" >4.102273</th>
#       <td id="T_bc3ed_row0_col0" class="data row0 col0" >661</td>
#       <td id="T_bc3ed_row0_col1" class="data row0 col1" >High Noon (1952)</td>
#     </tr>
#     <tr>
#       <th id="T_bc3ed_level0_row1" class="row_heading level0 row1" >4.023256</th>
#       <td id="T_bc3ed_row1_col0" class="data row1 col0" >589</td>
# ...

# %% [markdown]
# <h1> Get the data </h1>

# %%
users = pp.readUserData()
users = users.sort_values(by=['user_id','age']).reset_index().drop('index',axis=1)

items = pp.readItemData()
items = items.sort_values(by=['year','item_id']).reset_index().drop('index',axis=1)
items = items.dropna()

ratings = pp.readRatingData()
ratings = ratings.sort_values(by=['user_id','item_id']).reset_index().drop('index',axis=1)

# %%
count=0
yearnow=0
for i in range(len(items)):
    if(yearnow!=items['year'][i]):
        count+=1
        yearnow=items['year'][i]

temp2 = items.drop('item_id',axis=1)

plt.figure(figsize=(16,6))
for i in range(2,len(temp2.columns)-1):
    columnname = temp2.iloc[:,i].name
    temp3 = temp2.loc[:,['year',columnname]]
    temp3 = temp3.groupby(by=['year']).sum()
    plt.title(label=temp3.columns.name,fontsize=40,loc='center')
    plt.plot(temp3.index,temp3.iloc[:,0],label = temp3.columns[0])
    plt.xticks(rotation=90)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <h1> Based on Occupation </h1>

# %%
occup = pp.specifyByUserData(users, ratings, ["occupation"])
job = pp.getOccupationList()
occup = occup.drop('user_id',axis=1)
occup = occup.groupby(by=['occupation','item_id']).mean()
tick = job['occupation'].tolist()
pp.categorySimilarity(occup,tick,'occupation')

# %% [markdown]
# <h1>Age Category Query</h1>
# For presentation, if we want to show why the accuracy for age_category 6 is really not related to 7 (it's for the function below)

# %%
display(users.query('age_category >=6'))
# Out:
#      user_id  age  gender  occupation zip_code age_category
# 105      106   61       1          15    55125            6
# 210      211   66       1          16    32605            6
# 265      266   62       0           0    78756            6
# 317      318   65       1          15    06518            6
# 348      349   68       1          15    61455            6
# 350      351   61       1           3    49938            6
# 363      364   63       1           4    01810            6
# 422      423   64       1          13    91606            6
# 480      481   73       1          15    37771            7
# 519      520   62       1           7    12603            6
# 558      559   69       1           6    10022            6
# 563      564   65       1          15    94591            6
# 572      573   68       1          15    48911            6
# 584      585   69       1          10    98501            6
# 650      651   65       1          15    02903            6
# ...

# %% [markdown]
# <h1> Based on age category </h1>

# %%
occup = pp.specifyByUserData(users, ratings, ["age_category"])
occup = occup.drop('user_id',axis=1)
occup = occup.groupby(by=['age_category','item_id']).mean()

age = [f"{x*10+1} - {(x+1)*10}" for x in range(0,8)]
pp.categorySimilarity(occup,age,'age_category')

# %% [markdown]
# <h1>Specifying data to analyze based on user</h1>
# Returns a pandas data frame with the user_id, item_id, rating and any specified category from the user attributes. takes input from user data and ratings data

# %%
occup = pp.specifyByUserData(users, ratings, ["gender"])
occup
occup = occup.drop('user_id',axis=1)
occup = occup.groupby(by=['gender','item_id']).mean()
gender = ['female','male']
pp.categorySimilarity(occup,gender,'gender',size=(10,10))

# %% [markdown]
# <h1>Specifying data to analyze based on item</h1>
# Returns a pandas data frame with the item_id, item_id, rating and any specified category(only between "year" and "genre") from the item attributes, takes input from user data and ratings data

# %%
occup = saveyear = pp.specifyByItemData(items, ratings, "year")
occup = occup.drop('user_id',axis=1)
occup = occup.groupby(by=['year','item_id']).mean()

#saving only the year list
saveyear = saveyear['year'].drop_duplicates().reset_index().drop('index',axis=1)
saveyeartext = saveyear['year'].tolist()
pp.categorySimilarity(occup,saveyeartext,'year',size=(40,40),threshold=0)

# %%
occup = saveyear = pp.specifyByItemData(items, ratings, "year")
occup = occup.drop('item_id',axis=1)
occup = occup.groupby(by=['year','user_id']).mean()

#saving only the year list
saveyear = saveyear['year'].drop_duplicates().reset_index().drop('index',axis=1)
saveyeartext = saveyear['year'].tolist()
pp.categorySimilarity(occup,saveyeartext,'year',size=(40,40),threshold=0,setindex='user_id')

# %%
occup = saveyear = pp.specifyByItemData(items, ratings, "year_category")
occup = occup.drop('item_id',axis=1)
occup = occup.groupby(by=['year_category','user_id']).mean()

#saving only the year list
# saveyear = saveyear['year_category'].drop_duplicates().reset_index().drop('index',axis=1)
saveyeartext = ["1920s","1930s","1940s","1950s","1960s","1970s","1980s","1990s"]
pp.categorySimilarity(occup,saveyeartext,'year_category',size=(40,40),threshold=0,setindex='user_id')
